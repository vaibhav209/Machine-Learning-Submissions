# %%
#write a program to take input from the 3 users- excercise,food
print("****Health Management System****")

import datetime
def gettime():
    return datetime.datetime.now()

a=int(input("Enter 1:write and 2:read : "))
if a==1:
    b=int(input("Enter 1:Swapnil ,2:Sushant and 3:Rahul : "))
    if b==1:
        c=int(input("Enter 1:Exercise and 2: Food : "))
        if c==1:
            e=input("Excercise Type : ")
            print(e)
            file = open("swapnilExcercise.txt","a")
            file.write(str(gettime())+": "+ e +"\n")
            file.close()
        elif c==2:
            f=input("Food Type : ")
            print(f)
            file = open("swapnilFood.txt","a")
            file.write(str(gettime())+": "+ f +"\n")
            file.close()
        else:
            print("Wrong input")
            
    elif b==2:
        c=int(input("Enter 1:Exercise and 2: Food : "))
        if c==1:
            e=input("Excercise Type : ")
            print(e)
            
            file = open("sushantExcercise.txt","a")
            file.write(str(gettime())+": "+ e +"\n")
            file.close()
        elif c==2:
            f=input("Food Type : ")
            print(f)
            
            file = open("sushantFood.txt","a")
            file.write(str(gettime())+": "+ f +"\n")
            file.close()
        else:
            print("Wrong input")
            
    elif b==3:
        c=int(input("Enter 1:Exercise and 2: Food : "))
        if c==1:
            e=input("Excercise Type : ")
            print(e)
            
            file = open("rahulExcercise.txt","a")
            file.write(str(gettime())+": "+ e +"\n")
            file.close()
        elif c==2:
            f=input("Food Type : ")
            print(f)
            
            file = open("rahulFood.txt","a")
            file.write(str(gettime())+": "+ f +"\n")
            file.close()
        else:
            print("Wrong input")
    else:
        print("Wrong input")
    
elif a==2:
    b=int(input("Enter 1:Swapnil ,2:Sushant and 3:Rahul : "))
    if b==1:
        c=int(input("Enter 1:Exercise and 2: Food : "))
        if c==1:
            file = open("swapnilExcercise.txt","rt")
            e=file.read()
            print(e)

            file.close()
        elif c==2:
            file = open("swapnilFood.txt","rt")
            f=file.read()
            print(f)

            file.close()
        else:
            print("Wrong input")
            
    elif b==2:
        c=int(input("Enter 1:Exercise and 2: Food : "))
        if c==1:
            
            file = open("sushantExcercise.txt","rt")
            e=file.read()
            print(e)

            file.close()
        elif c==2:
           
            file = open("sushantFood.txt","rt")
            f=file.read()
            print(f)

            file.close()
        else:
            print("Wrong input")
            
    elif b==3:
        c=int(input("Enter 1:Exercise and 2: Food : "))
        if c==1:
         
            file = open("rahulExcercise.txt","rt")
            e=file.read()
            print(e)
            file.close()
        elif c==2:
            
            file = open("rahulFood.txt","rt")
            f=file.read()
            print(f)
            file.close()
        else:
            print("Wrong input")
            
    else:
        print("Wrong input")
else:
    print("Wrong input")
# Out:
# ****Health Management System****
# Enter 1:write and 2:read1
# Enter 1:Swapnil ,2:Sushant and 3:Rahul3
# Enter 1:Exercise and 2: Food1
# Excercise Typerun
# run
